# %%
from datetime import date
import time
import json
f=open('info.json',"r")
y=json.loads(f.read())
f.close()
op=1

login=input('Enter A. For Admin login\nEnter C. for user login\n')
if(login=='A'):
    print("1. To see all the available medicines\n2. Get the complete information about medinces stock\n3. Add the stock\n4. Release some stock\n5. Want to add new stock")
    opt=int(input("Enter the option"))
    if(opt==1):
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        for i in ls:
            print(i)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")    
    elif(opt==2):
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        for pair in y:
            print(pair,'\t',y[pair]['price'],'\t',y[pair]['qty'],'\t',y[pair]['manf-date'],'\t\t',y[pair]['exp-date'])
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    elif(opt==3):
        cont=1
        while(cont==1):       
            add=input("WHich medicine stock you want to add ")
            add=add.lower()
            num=int(input("How much you want to add "))
            if add not in y:
                 print("Entered medicine is not available ")
            else:
                 y[add]['qty']=y[add]['qty']+num              
            op=input("Do you want to add more(Yes/No) ")
            if(op=="Yes"):
                cont=1
            else:
                cont=0
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("((((((((((((((((((((((((((((((((((((((Successfully Added ))))))))))))))))))))))))))))))))))))))))))))))))))")
        
    elif(opt==4):
        cont=1
        while(cont==1):       
            add=input("WHich medicine stock you want to release ")
            add=add.lower()
            num=int(input("How much you want to release "))
            if add not in y:
                 print("Entered medicine is not available ")
            else:
                y[add]['qty']=y[add]['qty']-num
                if(y[add]['qty']<0):
                    print("That much stock is not available to release..... So we are making it 0 ")
                    y[add]['qty']=0
            op=input("Do you want to release more(Yes/No) ")
            if(op=="Yes"):
                cont=1
            else:
                cont=0
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("((((((((((((((((((((((((((((((((((((((Successfully Released ))))))))))))))))))))))))))))))))))))))))))))))))))")
        
    elif(opt==5):
        cont=1
        while(cont==1):
            add=input("WHich new medicine stock you want to add")
            add=add.lower()
            qty=int(input("How much quantity you want to add "))
            price=int(input("Enter its price "))
            manf=input("Enter its manufacturing date")
            exp=input("Enter its expiry date ")
            if add in y:
                print("It is already present so we are adding its quantity by given quantity ")
                y[add]['qty']= y[add]['qty']+qty
            else:
                y[add]['qty']=qty
                y[add]['price']=price
                y[add]['manf-date']=manf
                y[add]['exp-date']=exp
            op=input("Do you want to add more(Yes/No) ")
            if(op=="Yes"):
                cont=1
            else:
                cont=0
            print("((((((((((((((((((((((((((((((((((((((Successfully Done ))))))))))))))))))))))))))))))))))))))))))))))))))")
        
    else:
        print("Invalid operation number is entered ")
            
#     customer section        

if(login=='C'):
    op="Yes"
    while(op=="Yes"):
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        for pair in y:
            print(pair,'\t',y[pair]['price'],'\t',y[pair]['qty'],'\t',y[pair]['manf-date'],'\t\t',y[pair]['exp-date'])
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        med=input("Which medicine you want to buy ?")
        med=med.lower()
        rqty=int(input("how much tablets you want to buy ?"))
        if med not in y:
            print("Sorry this medicine is not present")
            continue
        req=y[med]
        if(req['qty']<rqty):
            print("Sorry we dont have enough stock!!  would you like to buy "+req['qty']+" tablets")
            res=input("(Yes/No)")
            if(res=="Yes"):
                buy=y[med]['qty']
                y[med]['qty']=0
                spend=y[med]['price']*buy
                print("************************************************************")
                print("Your bill is Rs",spend)
                print("Thank you")
                tdate=str(date.today())
                Time=time.localtime()
                currtime=time.strftime("%H:%M:%S",Time)
                sale={tdate:{'qty':buy,'time':currtime,'expenditure':spend,'date':tdate}}       
                f=open('sales.json','a')
                f.write(json.dumps(sale))
                f.close()
            else:
                print("**************************************************************")
                print("Sorry for inconvenience")
        
        else:
            y[med]['qty']=y[med]['qty']-rqty
            spend=y[med]['price']*rqty
            print("************************************************************")
            print("Your bill is Rs",spend)
            print("Thank you")
            tdate=str(date.today())
            Time=time.localtime()
            currtime=time.strftime("%H:%M:%S",Time)
            sale={tdate:{'qty':rqty,'time':currtime,'expenditure':spend,'date':tdate}}       
            f=open('sales.json','a')
            f.write(json.dumps(sale))
            f.close()
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        op=input("Do you want to purchase anything else (Yes/No)????")
f=open('info.json',"w")
f.write(json.dumps(y))
f.close()
